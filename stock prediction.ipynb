# %%
import pandas as pd
import matplotlib.pyplot as plt #for data visualization 
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
dataset=pd.read_csv("AAPL.csv")

# %%
dataset.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100323  469033600
# 1  1980-12-15  0.122210  0.122210  0.121652  0.121652   0.095089  175884800
# 2  1980-12-16  0.113281  0.113281  0.112723  0.112723   0.088110  105728000
# 3  1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090291   86441600
# 4  1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092908   73449600

# %%
dataset.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
dataset=pd.DataFrame(dataset)

# %%
dataset.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100323  469033600
# 1  1980-12-15  0.122210  0.122210  0.121652  0.121652   0.095089  175884800
# 2  1980-12-16  0.113281  0.113281  0.112723  0.112723   0.088110  105728000
# 3  1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090291   86441600
# 4  1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092908   73449600

# %%
data = pd.read_csv('AAPL.csv')

# %%
data.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100323  469033600
# 1  1980-12-15  0.122210  0.122210  0.121652  0.121652   0.095089  175884800
# 2  1980-12-16  0.113281  0.113281  0.112723  0.112723   0.088110  105728000
# 3  1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090291   86441600
# 4  1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092908   73449600

# %%
data.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['Date']=data['Date'].map(pd.Timestamp.toordinal)

numer_data=data.select_dtypes(include=[np.number])
plt.figure(1 , figsize = (17 , 8))
cor = sns.heatmap(numer_data.corr(), annot = True)
plt.show()

# %%
x=data.loc[:,'High':'Volume']
y=data.loc[:,'Open']

# %%
x.head()
# Out:
#        High       Low     Close  Adj Close     Volume
# 0  0.128906  0.128348  0.128348   0.100323  469033600
# 1  0.122210  0.121652  0.121652   0.095089  175884800
# 2  0.113281  0.112723  0.112723   0.088110  105728000
# 3  0.116071  0.115513  0.115513   0.090291   86441600
# 4  0.119420  0.118862  0.118862   0.092908   73449600

# %%
y.head()
# Out:
# 0    0.128348
# 1    0.122210
# 2    0.113281
# 3    0.115513
# 4    0.118862
# Name: Open, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.1,random_state = 0)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9999354520777648

# %%
Test_data=[[0.128906,0.128348,0.128348,0.100323,469033600]]
Test_data_df = pd.DataFrame(Test_data, columns=['High', 'Low', 'Close', 'Adj Close', 'Volume'])
prediction = lr.predict(Test_data_df)

# %%
print(prediction)
# Out:
# [0.12677883]
